# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
data = pd.read_csv('D:/Ai course/2.MachineLearning/insurance_pre.csv')
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(data,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error','absolute_error','poisson','friedman_mse','mae'],
           'max_features':['auto','log2'],'n_estimators':[50,100,1000]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,verbose=3,n_jobs=-1,refit=True)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson', 'friedman_mse', 'mae'],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [50, 100, 1000]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print('The R_score value of best parameter{} is:'.format(grid.best_params_),r_score)
# Out:
# The R_score value of best parameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 1000} is: 0.8738820343482823

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.213636      0.008039         0.012568    1.196981e-03
# 1        0.388576      0.002999         0.021744    1.465383e-03
# 2        3.859833      0.027263         0.189502    1.509967e-02
# 3        0.166361      0.002778         0.011769    3.988268e-04
# 4        0.316166      0.002821         0.020148    7.464422e-04
# 5        3.095845      0.028210         0.178730    5.293029e-03
# 6        0.829414      0.033442         0.010772    7.462640e-04
# 7        1.645266      0.067035         0.018951    8.916436e-04
# 8       16.359313      0.572955         0.168756    3.420096e-03
# 9        0.521825      0.031251         0.010573    4.888114e-04
# 10       1.034873      0.067606         0.018552    4.887922e-04
# 11      10.304859      0.556681         0.172347    5.930650e-03
# 12       0.287841      0.002863         0.010972    4.422006e-07
# ...
